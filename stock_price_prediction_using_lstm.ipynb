# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
google_stock_data = pd.read_csv('/content/GOOG.csv')
google_stock_data.head()
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
google_stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
google_stock_data = google_stock_data[['date','open','close']] # Extracting required columns
google_stock_data['date'] = pd.to_datetime(google_stock_data['date'].apply(lambda x: x.split()[0])) # Selecting only date
google_stock_data.set_index('date',drop=True,inplace=True) # Setting date column as index
google_stock_data.head()
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71

# %%
fg, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(google_stock_data['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(google_stock_data['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fg.show()

# %% [markdown]
# # Data Pre-Processing

# %%
from sklearn.preprocessing import MinMaxScaler
MMS = MinMaxScaler()
google_stock_data[google_stock_data.columns] = MMS.fit_transform(google_stock_data)

# %%
google_stock_data.shape
# Out:
# (1258, 2)

# %%
training_size = round(len(google_stock_data) * 0.80) # Selecting 80 % for training and 20 % for testing
training_size
# Out:
# 1006

# %%
train_data = google_stock_data[:training_size]
test_data  = google_stock_data[training_size:]

train_data.shape, test_data.shape
# Out:
# ((1006, 2), (252, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)

# %%
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((956, 50, 2), (956, 2), (202, 50, 2), (202, 2))

# %% [markdown]
# # Creating LSTM model

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, f1_score

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(train_seq, train_label, epochs=80,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/80
# 30/30 [==============================] - 6s 79ms/step - loss: 0.0078 - mean_absolute_error: 0.0600 - val_loss: 0.0212 - val_mean_absolute_error: 0.1262
# Epoch 2/80
# 30/30 [==============================] - 2s 52ms/step - loss: 8.3883e-04 - mean_absolute_error: 0.0229 - val_loss: 0.0069 - val_mean_absolute_error: 0.0691
# Epoch 3/80
# 30/30 [==============================] - 2s 51ms/step - loss: 5.6347e-04 - mean_absolute_error: 0.0169 - val_loss: 0.0037 - val_mean_absolute_error: 0.0487
# Epoch 4/80
# 30/30 [==============================] - 2s 58ms/step - loss: 5.3844e-04 - mean_absolute_error: 0.0163 - val_loss: 0.0041 - val_mean_absolute_error: 0.0518
# Epoch 5/80
# 30/30 [==============================] - 2s 82ms/step - loss: 5.1909e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0033 - val_mean_absolute_error: 0.0454
# Epoch 6/80
# 30/30 [==============================] - 2s 67ms/step - loss: 5.0669e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0042 - val_mean_absolute_error: 0.0529
# Epoch 7/80
# 30/30 [==============================] - 1s 48ms/step - loss: 5.1431e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0035 - val_mean_absolute_error: 0.0473
# Epoch 8/80
# 30/30 [==============================] - 1s 49ms/step - loss: 4.7243e-04 - mean_absolute_error: 0.0159 - val_loss: 0.0037 - val_mean_absolute_error: 0.0492
# Epoch 9/80
# 30/30 [==============================] - 2s 51ms/step - loss: 4.3674e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0041 - val_mean_absolute_error: 0.0525
# Epoch 10/80
# 30/30 [==============================] - 2s 51ms/step - loss: 4.1723e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0046 - val_mean_absolute_error: 0.0561
# Epoch 11/80
# 30/30 [==============================] - 2s 53ms/step - loss: 3.9744e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0050 - val_mean_absolute_error: 0.0592
# Epoch 12/80
# 30/30 [==============================] - 1s 50ms/step - loss: 4.2547e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0028 - val_mean_absolute_error: 0.0413
# Epoch 13/80
# 30/30 [==============================] - 2s 76ms/step - loss: 3.9278e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0035 - val_mean_absolute_error: 0.0473
# Epoch 14/80
# 30/30 [==============================] - 3s 89ms/step - loss: 3.5695e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0060 - val_mean_absolute_error: 0.0652
# Epoch 15/80
# 30/30 [==============================] - 1s 49ms/step - loss: 4.1085e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0091 - val_mean_absolute_error: 0.0824
# Epoch 16/80
# 30/30 [==============================] - 1s 50ms/step - loss: 3.9105e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0093 - val_mean_absolute_error: 0.0839
# Epoch 17/80
# 30/30 [==============================] - 2s 51ms/step - loss: 3.5135e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0058 - val_mean_absolute_error: 0.0631
# Epoch 18/80
# 30/30 [==============================] - 1s 48ms/step - loss: 3.2775e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0074 - val_mean_absolute_error: 0.0718
# Epoch 19/80
# 30/30 [==============================] - 2s 50ms/step - loss: 3.8723e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0035 - val_mean_absolute_error: 0.0468
# Epoch 20/80
# 30/30 [==============================] - 1s 48ms/step - loss: 3.5995e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0042 - val_mean_absolute_error: 0.0514
# Epoch 21/80
# 30/30 [==============================] - 2s 57ms/step - loss: 3.1546e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0054 - val_mean_absolute_error: 0.0605
# Epoch 22/80
# 30/30 [==============================] - 2s 81ms/step - loss: 3.0959e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0054 - val_mean_absolute_error: 0.0600
# Epoch 23/80
# 30/30 [==============================] - 2s 66ms/step - loss: 3.1964e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0065 - val_mean_absolute_error: 0.0674
# Epoch 24/80
# 30/30 [==============================] - 1s 49ms/step - loss: 2.8305e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0053 - val_mean_absolute_error: 0.0594
# Epoch 25/80
# 30/30 [==============================] - 1s 48ms/step - loss: 2.8076e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0062 - val_mean_absolute_error: 0.0654
# Epoch 26/80
# 30/30 [==============================] - 1s 48ms/step - loss: 2.8161e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0047 - val_mean_absolute_error: 0.0551
# Epoch 27/80
# 30/30 [==============================] - 1s 49ms/step - loss: 2.8169e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0044 - val_mean_absolute_error: 0.0526
# Epoch 28/80
# 30/30 [==============================] - 1s 49ms/step - loss: 2.7127e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0053 - val_mean_absolute_error: 0.0591
# Epoch 29/80
# 30/30 [==============================] - 1s 49ms/step - loss: 3.0648e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0054 - val_mean_absolute_error: 0.0609
# Epoch 30/80
# 30/30 [==============================] - 2s 70ms/step - loss: 2.9018e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0080 - val_mean_absolute_error: 0.0761
# Epoch 31/80
# 30/30 [==============================] - 2s 81ms/step - loss: 2.6602e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0063 - val_mean_absolute_error: 0.0668
# Epoch 32/80
# 30/30 [==============================] - 2s 59ms/step - loss: 2.9541e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0081 - val_mean_absolute_error: 0.0767
# Epoch 33/80
# 30/30 [==============================] - 2s 51ms/step - loss: 2.6162e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0025 - val_mean_absolute_error: 0.0378
# Epoch 34/80
# 30/30 [==============================] - 2s 50ms/step - loss: 2.9482e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0028 - val_mean_absolute_error: 0.0408
# Epoch 35/80
# 30/30 [==============================] - 1s 49ms/step - loss: 2.9265e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0030 - val_mean_absolute_error: 0.0419
# Epoch 36/80
# 30/30 [==============================] - 1s 48ms/step - loss: 2.5580e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0050 - val_mean_absolute_error: 0.0585
# Epoch 37/80
# 30/30 [==============================] - 1s 49ms/step - loss: 2.4077e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0043 - val_mean_absolute_error: 0.0525
# Epoch 38/80
# 30/30 [==============================] - 1s 48ms/step - loss: 2.4641e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0045 - val_mean_absolute_error: 0.0550
# Epoch 39/80
# 30/30 [==============================] - 2s 79ms/step - loss: 2.3280e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0030 - val_mean_absolute_error: 0.0431
# Epoch 40/80
# 30/30 [==============================] - 2s 78ms/step - loss: 2.3303e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0033 - val_mean_absolute_error: 0.0450
# Epoch 41/80
# 30/30 [==============================] - 2s 50ms/step - loss: 2.4086e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0030 - val_mean_absolute_error: 0.0433
# Epoch 42/80
# 30/30 [==============================] - 1s 49ms/step - loss: 2.1834e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0052 - val_mean_absolute_error: 0.0604
# Epoch 43/80
# 30/30 [==============================] - 2s 50ms/step - loss: 2.2506e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0052 - val_mean_absolute_error: 0.0598
# Epoch 44/80
# 30/30 [==============================] - 1s 49ms/step - loss: 2.1685e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0036 - val_mean_absolute_error: 0.0482
# Epoch 45/80
# 30/30 [==============================] - 1s 49ms/step - loss: 2.4760e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0065 - val_mean_absolute_error: 0.0688
# Epoch 46/80
# 30/30 [==============================] - 1s 49ms/step - loss: 2.3502e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0033 - val_mean_absolute_error: 0.0446
# Epoch 47/80
# 30/30 [==============================] - 2s 55ms/step - loss: 2.2199e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0058 - val_mean_absolute_error: 0.0632
# Epoch 48/80
# 30/30 [==============================] - 2s 79ms/step - loss: 2.4688e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0055 - val_mean_absolute_error: 0.0611
# Epoch 49/80
# 30/30 [==============================] - 2s 75ms/step - loss: 2.1156e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0038 - val_mean_absolute_error: 0.0496
# Epoch 50/80
# 30/30 [==============================] - 1s 49ms/step - loss: 2.0551e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0039 - val_mean_absolute_error: 0.0506
# Epoch 51/80
# 30/30 [==============================] - 1s 49ms/step - loss: 2.0377e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0038 - val_mean_absolute_error: 0.0495
# Epoch 52/80
# 30/30 [==============================] - 2s 52ms/step - loss: 2.0827e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0041 - val_mean_absolute_error: 0.0521
# Epoch 53/80
# 30/30 [==============================] - 1s 49ms/step - loss: 2.0213e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0042 - val_mean_absolute_error: 0.0530
# Epoch 54/80
# 30/30 [==============================] - 1s 49ms/step - loss: 1.9928e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0042 - val_mean_absolute_error: 0.0527
# Epoch 55/80
# 30/30 [==============================] - 2s 51ms/step - loss: 1.8756e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0040 - val_mean_absolute_error: 0.0517
# Epoch 56/80
# 30/30 [==============================] - 2s 66ms/step - loss: 2.0435e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0037 - val_mean_absolute_error: 0.0477
# Epoch 57/80
# 30/30 [==============================] - 2s 81ms/step - loss: 1.9198e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0038 - val_mean_absolute_error: 0.0496
# Epoch 58/80
# 30/30 [==============================] - 2s 78ms/step - loss: 1.9060e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0057 - val_mean_absolute_error: 0.0633
# Epoch 59/80
# 30/30 [==============================] - 1s 49ms/step - loss: 1.9018e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0070 - val_mean_absolute_error: 0.0703
# Epoch 60/80
# 30/30 [==============================] - 1s 49ms/step - loss: 1.7608e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0065 - val_mean_absolute_error: 0.0678
# Epoch 61/80
# 30/30 [==============================] - 2s 50ms/step - loss: 1.8889e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0041 - val_mean_absolute_error: 0.0513
# Epoch 62/80
# 30/30 [==============================] - 1s 49ms/step - loss: 1.7749e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0060 - val_mean_absolute_error: 0.0651
# Epoch 63/80
# 30/30 [==============================] - 1s 50ms/step - loss: 1.9016e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0054 - val_mean_absolute_error: 0.0608
# Epoch 64/80
# 30/30 [==============================] - 2s 52ms/step - loss: 1.9450e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0075 - val_mean_absolute_error: 0.0742
# Epoch 65/80
# 30/30 [==============================] - 2s 80ms/step - loss: 1.9147e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0080 - val_mean_absolute_error: 0.0762
# Epoch 66/80
# 30/30 [==============================] - 2s 70ms/step - loss: 1.7161e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0062 - val_mean_absolute_error: 0.0668
# Epoch 67/80
# 30/30 [==============================] - 1s 50ms/step - loss: 1.6504e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0076 - val_mean_absolute_error: 0.0738
# Epoch 68/80
# 30/30 [==============================] - 1s 48ms/step - loss: 1.6355e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0044 - val_mean_absolute_error: 0.0537
# Epoch 69/80
# 30/30 [==============================] - 1s 48ms/step - loss: 1.6896e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0055 - val_mean_absolute_error: 0.0630
# Epoch 70/80
# 30/30 [==============================] - 1s 48ms/step - loss: 1.6190e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0069 - val_mean_absolute_error: 0.0707
# Epoch 71/80
# 30/30 [==============================] - 1s 47ms/step - loss: 1.6155e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0071 - val_mean_absolute_error: 0.0710
# Epoch 72/80
# 30/30 [==============================] - 1s 48ms/step - loss: 1.6421e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0058 - val_mean_absolute_error: 0.0640
# Epoch 73/80
# 30/30 [==============================] - 2s 64ms/step - loss: 1.5633e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0070 - val_mean_absolute_error: 0.0699
# Epoch 74/80
# 30/30 [==============================] - 4s 123ms/step - loss: 1.4984e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0080 - val_mean_absolute_error: 0.0784
# Epoch 75/80
# 30/30 [==============================] - 2s 51ms/step - loss: 1.4902e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0042 - val_mean_absolute_error: 0.0521
# Epoch 76/80
# 30/30 [==============================] - 1s 48ms/step - loss: 1.4677e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0068 - val_mean_absolute_error: 0.0689
# Epoch 77/80
# 30/30 [==============================] - 2s 52ms/step - loss: 1.5273e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0059 - val_mean_absolute_error: 0.0629
# Epoch 78/80
# 30/30 [==============================] - 1s 48ms/step - loss: 1.4865e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0085 - val_mean_absolute_error: 0.0797
# Epoch 79/80
# 30/30 [==============================] - 2s 51ms/step - loss: 1.4157e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0060 - val_mean_absolute_error: 0.0637
# Epoch 80/80
# 30/30 [==============================] - 1s 48ms/step - loss: 1.8676e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0072 - val_mean_absolute_error: 0.0716

# %%
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 7/7 [==============================] - 1s 13ms/step
# array([[0.47385114, 0.47809622],
#        [0.47933242, 0.48377642],
#        [0.484493  , 0.4890841 ],
#        [0.4981725 , 0.5024659 ],
#        [0.5063011 , 0.51083267]], dtype=float32)

# %%
_,accuracy = model.evaluate(test_seq, test_label, verbose=0.0)
print('Accuracy:%.2f'%(accuracy*1000))
# Out:
# Accuracy:71.55

# %%
test_inverse_predicted = MMS.inverse_transform(test_predicted) # Inversing scaling on predicted data
test_inverse_predicted[:5]
# Out:
# array([[1549.4822, 1554.3348],
#        [1559.6439, 1564.8622],
#        [1569.2112, 1574.6991],
#        [1594.5719, 1599.5002],
#        [1609.6417, 1615.0067]], dtype=float32)

# %% [markdown]
# # Visualizing predicted and actual data

# %%
# Merging actual and predicted data for better visualization

gs_slic_data = pd.concat([google_stock_data.iloc[-202:].copy(),pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],index=google_stock_data.iloc[-202:].index)], axis=1)

# %%
gs_slic_data[['open','close']] = MMS.inverse_transform(gs_slic_data[['open','close']]) # Inverse scaling

# %%
gs_slic_data.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-08-24  1593.98  1588.20     1549.482178      1554.334839
# 2020-08-25  1582.07  1608.22     1559.643921      1564.862183
# 2020-08-26  1608.00  1652.38     1569.211182      1574.699097
# 2020-08-27  1653.68  1634.33     1594.571899      1599.500244
# 2020-08-28  1633.49  1644.41     1609.641724      1615.006714

# %%
gs_slic_data[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
gs_slic_data[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %% [markdown]
# # Predicting upcoming 10 days

# %%
# Creating a dataframe and adding 10 days to existing index

gs_slic_data = gs_slic_data.append(pd.DataFrame(columns=gs_slic_data.columns,index=pd.date_range(start=gs_slic_data.index[-1], periods=11, freq='D', closed='right')))

# %%
gs_slic_data['2021-06-09	':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2206.055664      2239.551270
# 2021-06-10  2494.01  2521.60     2219.877441      2254.876953
# 2021-06-11  2524.92  2513.93     2233.354492      2269.847656
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=gs_slic_data.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step

# %%
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
fg,ax=plt.subplots(figsize=(10,5))
ax.plot(gs_slic_data.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fg.show()

# %%
fg,ax=plt.subplots(figsize=(10,5))
ax.plot(gs_slic_data.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fg.show()
